# %%
import os
import locate_file
import matplotlib
# %matplotlib inline

working_directory = locate_file.locate_file()
print(working_directory)
os.chdir(working_directory)

import setup
from image_handling import read_image,display_image
# Out:
# /Users/ironstein/Documents/projects working directory/learning python/Python-tutorials/C library for image processing/8 - pointers to pointers and implementation of non maximum supression algorithm/
# platform : darwin

# %%
setup.compile()
# Out:
# compiling image_processing.c

# %%
image = read_image('sample_images/sample_image_1.png')
display_image(image)
print(type(image[0][0]))
# Out:
# <class 'numpy.uint8'>

# %%
import lib_image_processing
from gaussian import gaussian
g = gaussian()
kernel = g.generate_gaussian_smoothening_kernel(3)
smoothened_image = lib_image_processing.convolution(image,kernel,convert_to_uint8 = False)
display_image(smoothened_image)
# Out:
# 13495

# %%
[magnitude,angle] = lib_image_processing.sobel_operator(image)

# %%
tm = lib_image_processing.threshold(magnitude,threshold=10)
display_image(tm,invert=True,bnw=True)
magnitude = tm
display_image(magnitude)

# %%
display_image(angle)

# %%
from debug import time_this_function

# %%
nms = lib_image_processing.non_maximum_supression(magnitude,angle)
display_image(nms,bnw=True,threshold=0)

# %%
upper_threshold = 80
lower_threshold = 2
strong_image = []
weak_image = []
for row in m : 
    strong_image.append([])
    weak_image.append([])
    for pixel in row : 
        if(pixel > upper_threshold) :
            strong_image[-1].append(255)
            weak_image[-1].append(0)
        elif (pixel > lower_threshold) :
            strong_image[-1].append(0)
            weak_image[-1].append(255)
        else : 
            strong_image[-1].append(0)
            weak_image[-1].append(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-44aa944061bd> in <module>()
#       3 strong_image = []
#       4 weak_image = []
# ----> 5 for row in m :
#       6     strong_image.append([])
#       7     weak_image.append([])
#
# NameError: name 'm' is not defined
