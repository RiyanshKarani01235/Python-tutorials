# %%
import os
import locate_file
import matplotlib
# %matplotlib inline

working_directory = locate_file.locate_file()
print(working_directory)
os.chdir(working_directory)

import setup
from image_handling import read_image,display_image
# Out:
# /Users/ironstein/Documents/projects working directory/learning python/Python-tutorials/C library for image processing/8 - pointers to pointers and implementation of non maximum supression algorithm/
# platform : darwin

# %%
setup.compile()
# Out:
# compiling image_processing.c

# %%
image = read_image('sample_images/sample_image_4.png')
display_image(image)

# %%
import lib_image_processing
from gaussian import gaussian
g = gaussian()
kernel = g.generate_gaussian_smoothening_kernel(10)
image = lib_image_processing.convolution(image,kernel,convert_to_uint8 = False)
display_image(image)
# Out:
# 79747

# %%
[magnitude,angle] = lib_image_processing.sobel_operator(image)

# %%
display_image(magnitude)

# %%
display_image(angle)

# %%
from debug import time_this_function

# %%
m = []
@time_this_function
def test() :
    global m
    m = lib_image_processing.non_maximum_supression(magnitude,angle)
test()
display_image(m)
# Out:
# test -- elapsed_time -- 17.50493049621582 ms

# %%
n = max([max(element) for element in m])
n
# Out:
# 255

# %%
upper_threshold = 220
lower_threshold = 100
